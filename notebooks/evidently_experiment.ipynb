# %% [markdown]
# ## Data Validation Experiment

# %%
import pandas as pd
from evidently.dashboard import Dashboard
from evidently.tabs import DataDriftTab, CatTargetDriftTab
from evidently.model_profile import Profile
from evidently.profile_sections import DataDriftProfileSection
# Out:
# e:\end-to-end-machine-learning-project\End-To-End-MLOps-US-Visa-Prediction\visaEnv\Lib\site-packages\evidently\analyzers\__init__.py:3: UserWarning: analyzers are deprecated, use metrics instead
#   warnings.warn("analyzers are deprecated, use metrics instead")
# e:\end-to-end-machine-learning-project\End-To-End-MLOps-US-Visa-Prediction\visaEnv\Lib\site-packages\evidently\dashboard\__init__.py:8: UserWarning: dashboards are deprecated, use metrics instead
#   warnings.warn("dashboards are deprecated, use metrics instead")
# e:\end-to-end-machine-learning-project\End-To-End-MLOps-US-Visa-Prediction\visaEnv\Lib\site-packages\evidently\tabs\__init__.py:8: UserWarning: 'import evidently.tabs' is deprecated, use 'import evidently.dashboard.tabs'
#   warnings.warn(
# e:\end-to-end-machine-learning-project\End-To-End-MLOps-US-Visa-Prediction\visaEnv\Lib\site-packages\evidently\model_profile\__init__.py:8: UserWarning: model profiles are deprecated, use metrics instead
#   warnings.warn("model profiles are deprecated, use metrics instead")
# e:\end-to-end-machine-learning-project\End-To-End-MLOps-US-Visa-Prediction\visaEnv\Lib\site-packages\evidently\profile_sections\__init__.py:8: UserWarning: 'import evidently.profile_sections' is deprecated, use 'import evidently.model_profile.sections'
#   warnings.warn(

# %%
df = pd.read_csv("visadataset.csv")
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied
# 3       83434.0300         Year                  Y      Denied
# 4      149907.3900         Year                  Y   Certified

# %%
df.drop(columns = ['case_id'] , axis = 1 , inplace = True)

# %%
df.head()
# Out:
#   continent education_of_employee has_job_experience requires_job_training  \
# 0      Asia           High School                  N                     N
# 1      Asia              Master's                  Y                     N
# 2      Asia            Bachelor's                  N                     Y
# 3      Asia            Bachelor's                  N                     N
# 4    Africa              Master's                  Y                     N
#
#    no_of_employees  yr_of_estab region_of_employment  prevailing_wage  \
# 0            14513         2007                 West         592.2029
# 1             2412         2002            Northeast       83425.6500
# 2            44444         2008                 West      122996.8600
# 3               98         1897                 West       83434.0300
# 4             1082         2005                South      149907.3900
#
#   unit_of_wage full_time_position case_status
# 0         Hour                  Y      Denied
# 1         Year                  Y   Certified
# 2         Year                  Y      Denied
# 3         Year                  Y      Denied
# 4         Year                  Y   Certified

# %%
X = df.drop(columns = ['case_status'] , axis = 1)
y = df['case_status']
X.shape
# Out:
# (25480, 10)

# %%
from sklearn.model_selection import train_test_split

train_set , test_set = train_test_split(df , test_size = 0.2 , random_state = 42)

# %%
train_set.head()
# Out:
#            continent education_of_employee has_job_experience  \
# 2403            Asia           High School                  Y
# 6830   North America              Master's                  Y
# 878             Asia           High School                  Y
# 24061           Asia              Master's                  N
# 2109          Europe           High School                  N
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 2403                      Y             1411         2009
# 6830                      N              781         2012
# 878                       N              958         2005
# 24061                     N              900         1962
# 2109                      N             3533         1993
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 2403                  West         75107.37         Year                  Y
# 6830                  West        102403.56         Year                  Y
# 878                  South         89991.95         Year                  Y
# 24061                 West        128104.61         Year                  Y
# 2109                  West         12647.14         Year                  Y
#
#       case_status
# 2403       Denied
# 6830       Denied
# 878     Certified
# 24061      Denied
# 2109       Denied

# %%
data_drift_dashboard = Dashboard(tabs = [DataDriftTab()])

# %%
data_drift_dashboard.calculate(train_set , test_set)

# %%
data_drift_dashboard.show()
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_ece7dc0dc545494fb92772c0c0c4f7b4 = {"name": "evidently_dashboard_ece7dc0dc545494fb92772c0c0c4f7b4", "widgets": [{"type": "big_table", "title": "Drift is detected for 0.00% of features (0 out of 11). Dataset Drift is NOT detected.", "size": 2, "id": "0470108b-cbbb-4e2c-b839-743732e69d64", "details": "", "alertsPosition": "row", "alertStats": null, "params": {"rowsPerPage": 10, "columns": [{"title": "Feature", "field": "f1"}, {"title": "Type", "field": "f6"}, {"title": "Reference Distribution", "field": "f3", "type": "histogram", "options": {"xField": "x", "yField": "y", "color": "#ed0400"}}, {"title": "Current Distribution", "field": "f4", "type": "histogram", "options": {"xField": "x", "yField": "y", "color": "#ed0400"}}, {"title": "Data Drift", "field": "f2"}, {"title": "Stat Test", "field": "stattest_name"}, {"title": "Drift Score", "field": "f5"}], "data": [{"details": {"parts": [{"title": "Data drift", "id": "prevailing_wage_drift", "type": "widget"}, {"title": "Data distribution", "id": "prevailing_wage_distr"}], "insights": []}, "f1": "prevailing_wage", "f6": "num", "stattest_name": "Wasserstein distance (normed)", "f3": {"x": [2.1367, 31846.52803, 63690.91936000001, 95535.31069000001, 127379.70202000001, 159224.09335, 191068.48468000002, 222912.87601, 254757.26734000002, 286601.65867, 318446.05], "y": [7.383887412928979e-06, 6.766124247357412e-06, 6.989504943137654e-06, 5.647680211933579e-06, 2.9178140538467533e-06, 7.918460526278937e-07, 4.4676139156048517e-07, 2.9116518277562624e-07, 1.4327175660387986e-07, 2.4648904361957776e-08]}, "f4": {"x": [5.1868, 31925.69512, 63846.203440000005, 95766.71176, 127687.22008, 159607.7284, 191528.23672000002, 223448.74504, 255369.25336, 287289.76168000005, 319210.27], "y": [7.5676116118677235e-06, 6.8606454580376756e-06, 6.928268307534463e-06, 5.4221230232878425e-06, 2.8217170835477544e-06, 7.192612173749172e-07, 5.040976053396859e-07, 3.381142474839357e-07, 1.2909816722113887e-07, 3.68851906346112e-08]}, "f2": "Not Detected", "f5": 0.020639}, {"details": {"parts": [{"title": "Data drift", "id": "no_of_employees_drift", "type": "widget"}, {"title": "Data distribution", "id": "no_of_employees_distr"}], "insights": []}, "f1": "no_of_employees", "f6": "num", "stattest_name": "Wasserstein distance (normed)", "f3": {"x": [-26.0, 59423.8, 118873.6, 178323.40000000002, 237773.2, 297223.0, 356672.80000000005, 416122.60000000003, 475572.4, 535022.2000000001, 594472.0], "y": [1.6481756493016894e-05, 2.2032889318757875e-07, 6.684134961870364e-08, 1.1552825860022859e-08, 1.4853633248600819e-08, 7.426816624300403e-09, 9.077220318589389e-09, 4.1260092357224495e-09, 1.6504036942889783e-09, 3.300807388577963e-09]}, "f4": {"x": [-26.0, 60183.5, 120393.0, 180602.5, 240812.0, 301021.5, 361231.0, 421440.5, 481650.0, 541859.5, 602069.0], "y": [1.6276240483858407e-05, 2.3140029522505947e-07, 5.8664863578184096e-08, 1.629579543838447e-08, 9.777477263030682e-09, 6.518318175353788e-09, 3.259159087676894e-09, 3.259159087676894e-09, 0.0, 3.259159087676894e-09]}, "f2": "Not Detected", "f5": 0.014239}, {"details": {"parts": [{"title": "Data drift", "id": "yr_of_estab_drift", "type": "widget"}, {"title": "Data distribution", "id": "yr_of_estab_distr"}], "insights": []}, "f1": "yr_of_estab", "f6": "num", "stattest_name": "Wasserstein distance (normed)", "f3": {"x": [1800.0, 1821.6, 1843.2, 1864.8, 1886.4, 1908.0, 1929.6, 1951.2, 1972.8, 1994.4, 2016.0], "y": [0.00030661302982731685, 0.0005882427757427721, 0.0009334663352520534, 0.0013173004244432733, 0.0011038069073783406, 0.0014967258270829763, 0.0017669995348566666, 0.003252369323797909, 0.009913821297749807, 0.025616950840165235]}, "f4": {"x": [1800.0, 1821.6, 1843.2, 1864.8, 1886.4, 1908.0, 1929.6, 1951.2, 1972.8, 1994.4, 2016.0], "y": [0.00026346008488865744, 0.0007449561020989546, 0.0010084161869876199, 0.0011356038141752357, 0.0010447555090412276, 0.0016080150008721504, 0.001807881272166975, 0.0035067445781731643, 0.009620835513 ...
#     var additional_graphs_evidently_dashboard_ece7dc0dc545494fb92772c0c0c4f7b4 = {"prevailing_wage_distr": {"data": [{"histnorm": "probability", "marker": {"color": "#4d4d4d"}, "name": "Reference", "nbinsx": 10, "opacity": 0.6, "x": [75107.37, 102403.56, 89991.95, 128104.61, 12647.14, 91930.57, 99957.16, 13358.8, 96158.48, 28157.58, 59533.78, 2192.78, 11430.98, 292.0788, 130611.92, 85403.46, 85458.48, 95162.71, 127763.96, 122624.42, 127248.19, 106274.55, 97196.37, 70573.43, 44179.02, 334.0798, 52132.3, 58458.59, 12390.69, 3827.62, 65505.02, 81492.52, 112232.58, 125470.03, 229874.06, 3533

# %%
data_drift_dashboard.save("data_drift_test.html")

# %%
data_drift_profile = Profile(sections=[DataDriftProfileSection()])

# %%
data_drift_profile.calculate(train_set, test_set)

# %%
report = data_drift_profile.json()

# %%
report
# Out:
# '{"data_drift": {"name": "data_drift", "datetime": "2025-08-16 13:00:20.912078", "data": {"utility_columns": {"date": null, "id": null, "target": null, "prediction": null}, "num_feature_names": ["no_of_employees", "prevailing_wage", "yr_of_estab"], "cat_feature_names": ["case_status", "continent", "education_of_employee", "full_time_position", "has_job_experience", "region_of_employment", "requires_job_training", "unit_of_wage"], "text_feature_names": [], "datetime_feature_names": [], "target_names": null, "options": {"confidence": null, "drift_share": 0.5, "nbinsx": 10, "xbins": null}, "metrics": {"n_features": 11, "n_drifted_features": 0, "share_drifted_features": 0.0, "dataset_drift": false, "no_of_employees": {"current_small_hist": {"x": [-26.0, 60183.5, 120393.0, 180602.5, 240812.0, 301021.5, 361231.0, 421440.5, 481650.0, 541859.5, 602069.0], "y": [1.6276240483858407e-05, 2.3140029522505947e-07, 5.8664863578184096e-08, 1.629579543838447e-08, 9.777477263030682e-09, 6.518318175353788e-09, 3.259159087676894e-09, 3.259159087676894e-09, 0.0, 3.259159087676894e-09]}, "ref_small_hist": {"x": [-26.0, 59423.8, 118873.6, 178323.40000000002, 237773.2, 297223.0, 356672.80000000005, 416122.60000000003, 475572.4, 535022.2000000001, 594472.0], "y": [1.6481756493016894e-05, 2.2032889318757875e-07, 6.684134961870364e-08, 1.1552825860022859e-08, 1.4853633248600819e-08, 7.426816624300403e-09, 9.077220318589389e-09, 4.1260092357224495e-09, 1.6504036942889783e-09, 3.300807388577963e-09]}, "feature_type": "num", "stattest_name": "Wasserstein distance (normed)", "drift_score": 0.014239290623279301, "drift_detected": false}, "prevailing_wage": {"current_small_hist": {"x": [5.1868, 31925.69512, 63846.203440000005, 95766.71176, 127687.22008, 159607.7284, 191528.23672000002, 223448.74504, 255369.25336, 287289.76168000005, 319210.27], "y": [7.5676116118677235e-06, 6.8606454580376756e-06, 6.928268307534463e-06, 5.4221230232878425e-06, 2.8217170835477544e-06, 7.192612173749172e-07, 5.040976053396859e-07, 3.381142474839357e-07, 1.2909816722113887e-07, 3.68851906346112e-08]}, "ref_small_hist": {"x": [2.1367, 31846.52803, 63690.91936000001, 95535.31069000001, 127379.70202000001, 159224.09335, 191068.48468000002, 222912.87601, 254757.26734000002, 286601.65867, 318446.05], "y": [7.383887412928979e-06, 6.766124247357412e-06, 6.989504943137654e-06, 5.647680211933579e-06, 2.9178140538467533e-06, 7.918460526278937e-07, 4.4676139156048517e-07, 2.9116518277562624e-07, 1.4327175660387986e-07, 2.4648904361957776e-08]}, "feature_type": "num", "stattest_name": "Wasserstein distance (normed)", "drift_score": 0.02063904510723966, "drift_detected": false}, "yr_of_estab": {"current_small_hist": {"x": [1800.0, 1821.6, 1843.2, 1864.8, 1886.4, 1908.0, 1929.6, 1951.2, 1972.8, 1994.4, 2016.0], "y": [0.00026346008488865744, 0.0007449561020989546, 0.0010084161869876199, 0.0011356038141752357, 0.0010447555090412276, 0.0016080150008721504, 0.001807881272166975, 0.0035067445781731643, 0.009620835513692595, 0.02555562823419977]}, "ref_small_hist": {"x": [1800.0, 1821.6, 1843.2, 1864.8, 1886.4, 1908.0, 1929.6, 1951.2, 1972.8, 1994.4, 2016.0], "y": [0.00030661302982731685, 0.0005882427757427721, 0.0009334663352520534, 0.0013173004244432733, 0.0011038069073783406, 0.0014967258270829763, 0.0017669995348566666, 0.003252369323797909, 0.009913821297749807, 0.025616950840165235]}, "feature_type": "num", "stattest_name": "Wasserstein distance (normed)", "drift_score": 0.012742900762866232, "drift_detected": false}, "case_status": {"current_small_hist": {"x": ["Certified", "Denied"], "y": [3401, 1695]}, "ref_small_hist": {"x": ["Certified", "Denied"], "y": [13617, 6767]}, "feature_type": "cat", "stattest_name": "Jensen-Shannon distance", "drift_score": 0.0004786904643142934, "drift_detected": false}, "continent": {"current_small_hist": {"x": ["Africa", "Asia", "Europe", "North America", "Oceania", "South America"], "y": [112, 3421, 717, 640, 37, 169]}, "ref_small_hist": {"x": ["Africa", "As ...

# %%
import json

json_report = json.loads(report)
json_report
# Out:
# {'data_drift': {'name': 'data_drift',
#   'datetime': '2025-08-16 13:00:20.912078',
#   'data': {'utility_columns': {'date': None,
#     'id': None,
#     'target': None,
#     'prediction': None},
#    'num_feature_names': ['no_of_employees', 'prevailing_wage', 'yr_of_estab'],
#    'cat_feature_names': ['case_status',
#     'continent',
#     'education_of_employee',
#     'full_time_position',
#     'has_job_experience',
#     'region_of_employment',
#     'requires_job_training',
#     'unit_of_wage'],
#    'text_feature_names': [],
#    'datetime_feature_names': [],
#    'target_names': None,
#    'options': {'confidence': None,
#     'drift_share': 0.5,
#     'nbinsx': 10,
#     'xbins': None},
#    'metrics': {'n_features': 11,
#     'n_drifted_features': 0,
#     'share_drifted_features': 0.0,
#     'dataset_drift': False,
#     'no_of_employees': {'current_small_hist': {'x': [-26.0,
#        60183.5,
#        120393.0,
#        180602.5,
#        240812.0,
#        301021.5,
#        361231.0,
#        421440.5,
#        481650.0,
#        541859.5,
#        602069.0],
#       'y': [1.6276240483858407e-05,
#        2.3140029522505947e-07,
#        5.8664863578184096e-08,
#        1.629579543838447e-08,
#        9.777477263030682e-09,
#        6.518318175353788e-09,
#        3.259159087676894e-09,
#        3.259159087676894e-09,
#        0.0,
#        3.259159087676894e-09]},
#      'ref_small_hist': {'x': [-26.0,
#        59423.8,
#        118873.6,
#        178323.40000000002,
#        237773.2,
#        297223.0,
#        356672.80000000005,
#        416122.60000000003,
#        475572.4,
#        535022.2000000001,
#        594472.0],
#       'y': [1.6481756493016894e-05,
#        2.2032889318757875e-07,
#        6.684134961870364e-08,
#        1.1552825860022859e-08,
#        1.4853633248600819e-08,
#        7.426816624300403e-09,
#        9.077220318589389e-09,
#        4.1260092357224495e-09,
#        1.6504036942889783e-09,
#        3.300807388577963e-09]},
#      'feature_type': 'num',
#      'stattest_name': 'Wasserstein distance (normed)',
#      'drift_score': 0.014239290623279301,
#      'drift_detected': False},
#     'prevailing_wage': {'current_small_hist': {'x': [5.1868,
#        31925.69512,
#        63846.203440000005,
#        95766.71176,
#        127687.22008,
#        159607.7284,
#        191528.23672000002,
#        223448.74504,
#        255369.25336,
#        287289.76168000005,
#        319210.27],
#       'y': [7.5676116118677235e-06,
#        6.8606454580376756e-06,
#        6.928268307534463e-06,
#        5.4221230232878425e-06,
#        2.8217170835477544e-06,
#        7.192612173749172e-07,
#        5.040976053396859e-07,
#        3.381142474839357e-07,
#        1.2909816722113887e-07,
#        3.68851906346112e-08]},
#      'ref_small_hist': {'x': [2.1367,
#        31846.52803,
#        63690.91936000001,
#        95535.31069000001,
#        127379.70202000001,
#        159224.09335,
#        191068.48468000002,
#        222912.87601,
#        254757.26734000002,
#        286601.65867,
#        318446.05],
#       'y': [7.383887412928979e-06,
#        6.766124247357412e-06,
#        6.989504943137654e-06,
#        5.647680211933579e-06,
#        2.9178140538467533e-06,
#        7.918460526278937e-07,
#        4.4676139156048517e-07,
#        2.9116518277562624e-07,
#        1.4327175660387986e-07,
#        2.4648904361957776e-08]},
#      'feature_type': 'num',
#      'stattest_name': 'Wasserstein distance (normed)',
#      'drift_score': 0.02063904510723966,
#      'drift_detected': False},
#     'yr_of_estab': {'current_small_hist': {'x': [1800.0,
#        1821.6,
#        1843.2,
#        1864.8,
#        1886.4,
#        1908.0,
#        1929.6,
#        1951.2,
#        1972.8,
#        1994.4,
#        2016.0],
#       'y': [0.00026346008488865744,
#        0.0007449561020989546,
#        0.0010084161869876199,
#        0.0011356038141752357,
#        0.0010447555090412276,
#        0.0016080150008721504,
#        0.001807881272166975,
#        0.0035067445781731643,
#        0.009620835513692595,
#        0.02555562823419977]},
#      'ref_small_hist': {'x': [1800.0,
#        1821.6,
#        1843.2,
#        1864.8,
#        1886.4,
#        1908.0,
#        1929.6,
#        1951.2,
#        1972.8,
#        1994.4,
#        2016.0],
#       'y': [0.00030661302982731685,
#        0.0005882427757427721,
#        0.0009334663352520534,
#        0.0013173004244432733,
#        0.0011038069073783406,
#        0.0014967258270829763,
#        0.0017669995348566666,
#        0.003252369323797909,
#        0.009913821297749807,
#        0.025616950840165235]},
#      'feature_type': 'num',
#      'stattest_name': 'Wasserstein distance (normed)',
#      'drift_score': 0.012742900762866232,
#      'drift_detected': False},
#     'case_status': {'current_small_hist': {'x': ['Certified', 'Denied'],
#       'y': [3401, 1695]},
#      'ref_small_hist': {'x': ['Certified', 'Denied'], 'y': [13617, 6767]},
#      'feature_type': 'cat',
#      'stattest_name': 'Jensen-Shannon distance',
#      'drift_score': 0.0004786904643142934,
#      'drift_detected': False},
#     'continent': {'current_small_hist': {'x': ['Africa',
#        'Asia',
#        'Europe',
#        'North America',
#        'Oceania',
#        'South America'],
#       'y': [112, 3421, 717, 640, 37, 169]},
#      'ref_small_hist': {'x': ['Africa',
#        'Asia',
#        'Europe',
#        'North America',
#        'Oceania',
#        'South America'],
#       'y': [439, 13440, 3015, 2652, 155, 683]},
#      'feature_type': 'cat',
#      'stattest_name': 'Jensen-Shannon distance',
#      'drift_score': 0.009769236150461257,
#      'drift_detected': False},
#     'education_of_employee': {'current_small_hist': {'x': ["Bachelor's",
#        'Doctorate',
#        'High School',
#        "Master's"],
#       'y': [2026, 411, 680, 1979]},
#      'ref_small_hist': {'x': ["Bachelor's",
#        'Doctorate',
#        'High School',
#        "Master's"],
#       'y': [8208, 1781, 2740, 7655]},
#      'feature_type': 'cat',
#      'stattest_name': 'Jensen-Shannon distance',
#      'drift_score': 0.011398088610204615,
#      'drift_detected': False},
#     'full_time_position': {'current_small_hist': {'x': ['N', 'Y'],
#       'y': [548, 4548]},
#      'ref_small_hist': {'x': ['N', 'Y'], 'y': [2159, 18225]},
#      'feature_type': 'cat',
#      'stattest_name': 'Jensen-Shannon distance',
#      'drift_score': 0.001853762874361406,
#      'drift_detected': False},
#     'has_job_experience': {'current_small_hist': {'x': ['N', 'Y'],
#       'y': [2135, 2961]},
#      'ref_small_hist': {'x': ['N', 'Y'], 'y': [8543, 11841]},
#      'feature_type': 'cat',
#      'stattest_name': 'Jensen-Shannon distance',
#      'drift_score': 0.00010545993315477583,
#      'drift_detected': False},
#     'region_of_employment': {'current_small_hist': {'x': ['Island',
#        'Midwest',
#        'Northeast',
#        'South',
#        'West'],
#       'y': [61, 883, 1449, 1395, 1308]},
#      'ref_small_hist': {'x': ['Island',
#        'Midwest',
#        'Northeast',
#        'South',
#        'West'],
#       'y': [314, 3424, 5746, 5622, 5278]},
#      'feature_type': 'cat',
#      'stattest_name': 'Jensen-Shannon distance',
#      'drift_score': 0.011645035145855645,
#      'drift_detected': False},
#     'requires_job_training': {'current_small_hist': {'x': ['N', 'Y'],
#       'y': [4538, 558]},
#      'ref_small_hist': {'x': ['N', 'Y'], 'y': [17987, 2397]},
#      'feature_type': 'cat',
#      'stattest_name': 'Jensen-Shannon distance',
#      'drift_score': 0.009021487564355836,
#      'drift_detected': False},
#     'unit_of_wage': {'current_small_hist': {'x': ['Hour',
#        'Month',
#        'Week',
#        'Year'],
#       'y': [453, 17, 50, 4576]},
#      'ref_small_hist': {'x': ['Hour', 'Month', 'Week', 'Year'],
#       'y': [1704, 72, 222, 18386]},
#      'feature_type': 'cat',
#      'stattest_name': 'Jensen-Shannon distance',
#      'drift_score': 0.007642977610623218,
#      'drift_detected': False}}}},
#  'timestamp': '2025-08-16 13:00:23.591561'}

# %%
n_features = json_report["data_drift"]["data"]["metrics"]["n_features"]
n_drifted_features = json_report["data_drift"]["data"]["metrics"]["n_drifted_features"]
data_drift_percentage = (n_drifted_features / n_features) * 100

data_drift_percentage
# Out:
# 0.0

# %%
drift_status = json_report["data_drift"]["data"]["metrics"]["dataset_drift"]
drift_status
# Out:
# False
